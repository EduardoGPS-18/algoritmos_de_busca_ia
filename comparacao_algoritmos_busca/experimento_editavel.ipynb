# %%
from src.helpers.editable_graph import display_editable_graph
import networkx as nx

G = nx.DiGraph()

display_editable_graph(G, display_in_notebook=True)
# Out:
# Address already in use
# Port 8050 is in use by another program. Either identify and stop that program, or start the server with a different port.
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# /Users/eduardosilva/.pyenv/versions/3.14.2/lib/python3.14/site-packages/IPython/core/interactiveshell.py:3709: UserWarning:
#
# To exit: use 'exit', 'quit', or Ctrl-D.
